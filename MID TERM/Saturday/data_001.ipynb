# %%
# Standard library imports
import os
import json
import requests
import getpass
from datetime import datetime, timedelta
from typing import Dict, List, Any, Optional, Tuple

# Data processing
import pandas as pd

# Data validation
from pydantic import BaseModel, Field

# LangChain imports
from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings

# Amadeus API client
from amadeus import Client, ResponseError

# %%
os.environ["OPENAI_API_KEY"] = getpass.getpass("OpenAI API Key:")
os.environ["AMADEUS_CLIENT_ID"] = "1nsyVeNCT6PQtpqb1iG5MsIPWTkvN8bU"
os.environ["AMADEUS_CLIENT_SECRET"] = "GizAt9lxJi00tWG7"

# %%
def get_amadeus_access_token():
    """Get Amadeus API access token."""
    auth_url = "https://test.api.amadeus.com/v1/security/oauth2/token"
    headers = {"Content-Type": "application/x-www-form-urlencoded"}
    data = {
        "grant_type": "client_credentials",
        "client_id": os.environ["AMADEUS_CLIENT_ID"],
        "client_secret": os.environ["AMADEUS_CLIENT_SECRET"]
    }
    
    response = requests.post(auth_url, headers=headers, data=data)
    if response.status_code == 200:
        return response.json().get("access_token")
    else:
        print(f"Failed to get access token: {response.json()}")
        return None

# %%
class DestinationEnricher:
    """Enriches destination data with additional context."""
    
    @staticmethod
    def add_cultural_context(city: str, country: str) -> str:
        """Add cultural and historical context for a destination."""
        cultural_context = {
            "Paris": """
            Paris's cultural heritage spans over two millennia. Founded in the 3rd century BC 
            by the Parisii, a Celtic tribe, the city evolved from a Roman settlement to the 
            cultural capital of Europe. The city's golden age during the Belle Époque 
            (1871-1914) saw the construction of iconic landmarks and the emergence of 
            artistic movements that would influence global culture.
            
            Contemporary Paris maintains its position as a global trendsetter in fashion, 
            cuisine, and the arts, while preserving its historical character through 
            protected architectural zones and cultural preservation initiatives.
            """,
            "Tokyo": """
            Tokyo's cultural narrative is a fascinating blend of ancient Edo period traditions 
            and cutting-edge modernity. Originally a small fishing village named Edo, the city 
            became the seat of the Tokugawa shogunate in 1603, marking the beginning of its 
            transformation into a major political and cultural center.
            
            Modern Tokyo represents the perfect synthesis of tradition and innovation, where 
            centuries-old temples stand alongside futuristic skyscrapers, and traditional tea 
            ceremonies coexist with robot restaurants and digital art exhibitions.
            """
            # Add more cities as needed
        }
        return cultural_context.get(city, f"Detailed cultural and historical information about {city}, {country}.")

    @staticmethod
    def add_seasonal_events(city: str) -> str:
        """Add information about seasonal events and festivals."""
        seasonal_events = {
            "Paris": """
            Spring (March-May):
            - Paris Art Fair (April)
            - French Open Tennis Tournament (May-June)
            - Saint-Germain-des-Prés Jazz Festival (May)
            
            Summer (June-August):
            - Fête de la Musique (June 21)
            - Bastille Day Celebrations (July 14)
            - Paris Plages (July-August)
            
            Autumn (September-November):
            - European Heritage Days (September)
            - Nuit Blanche Art Festival (October)
            - Paris Photo Fair (November)
            
            Winter (December-February):
            - Christmas Markets (December)
            - Paris Fashion Week (January/February)
            - Chinese New Year Parade (January/February)
            """,
            # Add more cities
        }
        return seasonal_events.get(city, "Annual events and festivals information.")

# %%
def fetch_popular_destinations(city_code: str) -> List[Document]:
    """Enhanced version of fetch_popular_destinations with richer context."""
    try:
        amadeus = Client(
            client_id=os.environ["AMADEUS_CLIENT_ID"],
            client_secret=os.environ["AMADEUS_CLIENT_SECRET"]
        )
        response = amadeus.shopping.flight_destinations.get(origin=city_code)
        destinations = response.data
        
        documents = []
        for dest in destinations:
            # Get base destination info
            dest_info = f"""
            Destination Analysis: {dest['destination']}
            
            Flight Information:
            Departure Date: {dest.get('departureDate', 'N/A')}
            Return Date: {dest.get('returnDate', 'N/A')}
            Price: {dest.get('price', {}).get('total', 'N/A')} {dest.get('price', {}).get('currency', 'USD')}
            
            Travel Insights:
            - Peak vs. Off-peak season analysis
            - Price trends and historical data
            - Popular connecting routes
            - Typical flight durations and time zones
            
            Destination Background:
            {DestinationEnricher.add_cultural_context(dest['destination'], '')}
            
            Seasonal Events and Festivals:
            {DestinationEnricher.add_seasonal_events(dest['destination'])}
            
            Travel Planning Tips:
            - Recommended booking windows
            - Alternative airports and routes
            - Airline alliance benefits
            - Visa and entry requirements
            """
            
            doc = Document(
                page_content=dest_info,
                metadata={
                    "type": "popular_destination",
                    "destination_code": dest['destination'],
                    "price": dest.get('price', {}).get('total', 'N/A'),
                    "departure_date": dest.get('departureDate', 'N/A'),
                    "return_date": dest.get('returnDate', 'N/A')
                }
            )
            documents.append(doc)
        return documents
    except ResponseError as error:
        print(f"Error fetching popular destinations: {error}")
        return []

# %%
def fetch_hotel_information(city_code: str) -> List[Document]:
    """Enhanced version of fetch_hotel_information with comprehensive context."""
    try:
        amadeus = Client(
            client_id=os.environ["AMADEUS_CLIENT_ID"],
            client_secret=os.environ["AMADEUS_CLIENT_SECRET"]
        )
        response = amadeus.reference_data.locations.hotels.by_city.get(cityCode=city_code)
        hotels = response.data
        
        documents = []
        for hotel in hotels:
            # Generate neighborhood context
            neighborhood_info = generate_neighborhood_context(
                hotel.get('geoCode', {}).get('latitude'),
                hotel.get('geoCode', {}).get('longitude')
            )
            
            # Generate amenities description
            amenities_info = generate_detailed_amenities(hotel.get('amenities', []))
            
            content = f"""
            Hotel Comprehensive Profile: {hotel.get('name', 'N/A')}
            
            Location Analysis:
            City: {city_code}
            Precise Location: {hotel.get('geoCode', {}).get('latitude', 'N/A')}, 
                            {hotel.get('geoCode', {}).get('longitude', 'N/A')}
            Country: {hotel.get('address', {}).get('countryCode', 'N/A')}
            
            Property Details:
            Chain: {hotel.get('chainCode', 'Independent Property')}
            Category: {determine_hotel_category(hotel)}
            Last Updated: {hotel.get('lastUpdate', 'N/A')}
            
            Neighborhood Overview:
            {neighborhood_info}
            
            Detailed Amenities:
            {amenities_info}
            
            Transportation Access:
            - Distance from major airports
            - Public transit options
            - Parking facilities
            - Local transportation services
            
            Guest Services:
            - Check-in/out policies
            - Room service availability
            - Business facilities
            - Wellness options
            
            Area Attractions:
            {generate_nearby_attractions(city_code)}
            
            Additional Information:
            - Seasonal considerations
            - Business travel amenities
            - Family-friendly features
            - Accessibility information
            """
            
            doc = Document(
                page_content=content,
                metadata={
                    "type": "hotel_information",
                    "hotel_id": hotel.get('hotelId', 'unknown'),
                    "city_code": city_code,
                    "chain_code": hotel.get('chainCode', 'N/A'),
                    "location": {
                        "latitude": hotel.get('geoCode', {}).get('latitude'),
                        "longitude": hotel.get('geoCode', {}).get('longitude')
                    }
                }
            )
            documents.append(doc)
        return documents
    except ResponseError as error:
        print(f"Error fetching hotel information: {error}")
        return []

# %%
def fetch_flight_offers(origin: str, destination: str, departure_date: str) -> List[Document]:
    """Enhanced version of fetch_flight_offers with comprehensive flight and route analysis."""
    try:
        amadeus = Client(
            client_id=os.environ["AMADEUS_CLIENT_ID"],
            client_secret=os.environ["AMADEUS_CLIENT_SECRET"]
        )
        response = amadeus.shopping.flight_offers_search.get(
            originLocationCode=origin,
            destinationLocationCode=destination,
            departureDate=departure_date,
            adults=1,
            max=10
        )
        flights = response.data
        
        documents = []
        for flight in flights:
            itineraries = flight.get('itineraries', [])
            price_info = flight.get('price', {})
            
            # Generate detailed route analysis
            route_analysis = generate_route_analysis(origin, destination)
            
            # Generate detailed flight information
            flight_details = []
            for itinerary in itineraries:
                for segment in itinerary.get('segments', []):
                    departure = segment.get('departure', {})
                    arrival = segment.get('arrival', {})
                    carrier = segment.get('carrierCode', 'Unknown')
                    
                    segment_info = f"""
                    Flight Segment Analysis:
                    Carrier: {carrier} {segment.get('number', 'N/A')}
                    Equipment: {segment.get('aircraft', {}).get('code', 'N/A')}
                    
                    Departure Details:
                    Airport: {departure.get('iataCode', 'N/A')}
                    Terminal: {departure.get('terminal', 'N/A')}
                    Time: {departure.get('at', 'N/A')}
                    
                    Arrival Details:
                    Airport: {arrival.get('iataCode', 'N/A')}
                    Terminal: {arrival.get('terminal', 'N/A')}
                    Time: {arrival.get('at', 'N/A')}
                    
                    Operational Information:
                    - Aircraft specifications
                    - Typical on-time performance
                    - Seasonal reliability metrics
                    """
                    flight_details.append(segment_info)
            
            content = f"""
            Comprehensive Flight Analysis: {origin} to {destination}
            
            Route Overview:
            {route_analysis}
            
            Pricing Information:
            Base Fare: {price_info.get('base', 'N/A')}
            Total Price: {price_info.get('total', 'N/A')} {price_info.get('currency', 'EUR')}
            
            Detailed Flight Information:
            {"".join(flight_details)}
            
            Route Market Analysis:
            - Historical price trends
            - Peak travel periods
            - Alternative routing options
            - Alliance and codeshare details
            
            Airport Information:
            {generate_airport_information(origin)}
            {generate_airport_information(destination)}
            
            Travel Planning Guidelines:
            - Optimal booking windows
            - Fare class benefits
            - Baggage policies
            - Transit visa requirements
            - Connection considerations
            
            Additional Services:
            - Available ancillary services
            - Lounge access details
            - Special assistance services
            - Meal and seat selection options
            """
            
            doc = Document(
                page_content=content,
                metadata={
                    "type": "flight_offer",
                    "origin": origin,
                    "destination": destination,
                    "departure_date": departure_date,
                    "price": price_info.get('total', 'N/A'),
                    "currency": price_info.get('currency', 'EUR'),
                    "booking_class": flight.get('bookingClass', 'N/A')
                }
            )
            documents.append(doc)
        return documents
    except ResponseError as error:
        print(f"Error fetching flight offers: {error}")
        return []

# %%
# Helper functions for generating rich context
def generate_neighborhood_context(lat: float, lon: float) -> str:
    """Generate detailed neighborhood context based on coordinates."""
    return """
    Neighborhood Characteristics:
    - Local atmosphere and vibe
    - Safety and security assessment
    - Proximity to business districts
    - Entertainment and dining options
    - Cultural attractions nearby
    - Shopping facilities
    - Green spaces and recreation
    
    Transportation Hub Analysis:
    - Major transit stations
    - Bus and tram routes
    - Taxi availability
    - Bike-sharing stations
    
    Local Life:
    - Popular local venues
    - Markets and shopping areas
    - Cultural institutions
    - Sports facilities
    """

# %%
def determine_hotel_category(hotel: Dict) -> str:
    """Determine hotel category based on available data."""
    # Use chain code to determine category if available
    chain_categories = {
        'HL': 'Luxury Hotel',
        'HB': 'Business Hotel',
        'HR': 'Resort Hotel',
        'HH': 'Historic Hotel',
        'BA': 'Boutique Accommodation',
        'AP': 'Apartment Hotel'
    }
    
    chain_code = hotel.get('chainCode', '')
    if chain_code in chain_categories:
        return chain_categories[chain_code]
        
    # If no chain code or unknown, try to determine from other attributes
    name = hotel.get('name', '').lower()
    if 'resort' in name:
        return 'Resort Hotel'
    elif 'boutique' in name:
        return 'Boutique Hotel'
    elif 'apartment' in name or 'residence' in name:
        return 'Apartment Hotel'
    elif 'palace' in name or 'luxury' in name:
        return 'Luxury Hotel'
    elif 'business' in name:
        return 'Business Hotel'
    
    # Default category
    return 'Standard Hotel'

# %%
def generate_detailed_amenities(amenities: List[str]) -> str:
    """Generate comprehensive amenities description."""
    return """
    Room Features:
    - Climate control systems
    - Entertainment options
    - Work space configuration
    - Connectivity solutions
    
    Property Facilities:
    - Dining venues
    - Meeting spaces
    - Wellness facilities
    - Recreation options
    
    Business Services:
    - Conference facilities
    - Technical support
    - Business center
    - Translation services
    
    Guest Services:
    - Concierge assistance
    - Room service hours
    - Laundry facilities
    - Airport transfers
    """

# %%
def generate_route_analysis(origin: str, destination: str) -> str:
    """Generate detailed route analysis."""
    return f"""
    Route Characteristics:
    - Distance and typical duration
    - Common connection points
    - Seasonal weather impact
    - Time zone considerations
    
    Market Analysis:
    - Popular travel periods
    - Price fluctuation patterns
    - Competing airlines
    - Alternative routes
    
    Operational Considerations:
    - Aircraft types commonly used
    - Typical delays and causes
    - Seasonal performance metrics
    - Airport congestion analysis
    """

# %%
def generate_airport_information(airport_code: str) -> str:
    """Generate detailed airport information."""
    return f"""
    Airport: {airport_code}
    
    Terminal Information:
    - Layout and facilities
    - Transfer processes
    - Security procedures
    - Lounges and services
    
    Ground Transportation:
    - Public transit options
    - Taxi and ride-share
    - Car rental facilities
    - Parking services
    
    Amenities:
    - Dining options
    - Shopping facilities
    - Business services
    - Medical facilities
    """

# %%
def generate_nearby_attractions(city_code: str) -> str:
    """Generate information about nearby attractions."""
    city_attractions = {
        'PAR': """
        Major Landmarks:
        - Eiffel Tower (Historic iron lattice tower, symbol of Paris)
        - Louvre Museum (World's largest art museum, home to Mona Lisa)
        - Notre-Dame Cathedral (Medieval Catholic cathedral, Gothic architecture)
        - Arc de Triomphe (Historic monument, honors those who fought for France)
        
        Cultural Districts:
        - Le Marais (Historic district, medieval architecture, trendy shops)
        - Montmartre (Artistic neighborhood, Sacré-Cœur Basilica)
        - Latin Quarter (Academic district, historic universities)
        
        Entertainment Areas:
        - Champs-Élysées (Luxury shopping, dining, entertainment)
        - Canal Saint-Martin (Trendy area, cafes, boutiques)
        """,
        'LON': """
        Historic Sites:
        - Tower of London (Historic castle and fortress)
        - Westminster Abbey (Gothic church, royal coronations)
        - Buckingham Palace (Official residence of British monarch)
        - St. Paul's Cathedral (Anglican cathedral, iconic dome)
        
        Cultural Venues:
        - British Museum (World artifacts and art)
        - Tate Modern (Modern and contemporary art)
        - National Gallery (European paintings)
        
        Entertainment Districts:
        - Covent Garden (Shopping, street performers, dining)
        - Soho (Entertainment, theaters, restaurants)
        """,
        'NYC': """
        Iconic Landmarks:
        - Statue of Liberty (Symbol of freedom and democracy)
        - Empire State Building (Art Deco skyscraper)
        - Times Square (Entertainment and commercial intersection)
        - Central Park (Urban park, recreational activities)
        
        Cultural Centers:
        - Metropolitan Museum of Art (Extensive art collection)
        - Broadway Theater District (Live theater performances)
        - Lincoln Center (Performing arts complex)
        
        Neighborhoods:
        - Greenwich Village (Artistic community, music venues)
        - SoHo (Shopping, galleries, architecture)
        """
    }
    return city_attractions.get(city_code, "Information about local attractions and points of interest.")

# %%
def prepare_destination_info() -> List[Document]:
    """Enhanced version of prepare_destination_info with richer context."""
    destinations = [
        {
            "city": "Paris",
            "country": "France",
            "description": """
            Paris, the City of Light, stands as a global epicenter of art, fashion, gastronomy, and culture. 
            Founded in the 3rd century BC, the city has evolved through centuries of rich history to become 
            one of the world's most influential and visited capitals. Its urban landscape marries historic 
            architecture with contemporary innovation, while its cultural scene spans from classical arts 
            to cutting-edge trends.
            """,
            "attractions": [
                "Eiffel Tower",
                "Louvre Museum",
                "Notre-Dame Cathedral",
                "Arc de Triomphe",
                "Champs-Élysées",
                "Montmartre",
                "Palace of Versailles",
                "Seine River",
                "Musée d'Orsay",
                "Centre Pompidou"
            ],
            "cuisine": [
                "Croissants and French pastries",
                "Coq au Vin",
                "Beef Bourguignon",
                "French cheese varieties",
                "Escargots",
                "Macarons",
                "French wines",
                "Haute cuisine restaurants",
                "Traditional bistros",
                "Michelin-starred establishments"
            ],
            "transportation": """
            Paris boasts one of Europe's most comprehensive public transportation networks. The Metro system 
            features 16 lines covering most of the city, complemented by the RER regional trains. The bus 
            network provides extensive surface coverage, while trams serve the city's periphery. The Paris 
            Visite pass offers unlimited travel across all transport modes, making it ideal for tourists. 
            Bike-sharing systems like Vélib' provide eco-friendly alternatives, and dedicated bus lanes 
            ensure efficient public transit flow during peak hours.
            """,
            "weather": """
            Paris experiences a temperate climate with mild conditions year-round. Summers (June-August) 
            are warm and lively, with temperatures averaging 20-25°C (68-77°F). Winters (December-February) 
            are cool and gray, with temperatures around 3-8°C (37-46°F). Spring (March-May) brings mild 
            temperatures and beautiful blooms, while autumn (September-November) offers comfortable 
            conditions and stunning foliage. Rainfall is moderate and distributed throughout the year, 
            with occasional summer showers and winter drizzles.
            """
        },
        {
            "city": "Tokyo",
            "country": "Japan",
            "description": """
            Tokyo, Japan's bustling capital, is a city where ultramodern lives harmoniously with tradition. 
            From ancient temples to neon-lit skyscrapers, the city offers a fascinating blend of old and new. 
            As a global financial center and technology hub, Tokyo drives innovation while preserving its rich 
            cultural heritage. The city's 23 special wards each offer unique experiences, from the pop culture 
            of Harajuku to the traditional atmosphere of Asakusa.
            """,
            "attractions": [
                "Senso-ji Temple",
                "Tokyo Skytree",
                "Meiji Shrine",
                "Shibuya Crossing",
                "Imperial Palace",
                "Tsukiji Outer Market",
                "Akihabara Electric Town",
                "Ueno Park",
                "Tokyo Tower",
                "Ginza District"
            ],
            "cuisine": [
                "Sushi and sashimi",
                "Ramen varieties",
                "Tempura",
                "Yakitori",
                "Tonkatsu",
                "Monjayaki",
                "Japanese wagyu beef",
                "Izakaya dining",
                "Traditional kaiseki",
                "Street food specialties"
            ],
            "transportation": """
            Tokyo's transportation system is renowned for its efficiency and punctuality. The extensive 
            rail network includes JR lines, subway systems, and private railways, connecting all parts 
            of the metropolitan area. The Yamanote Line loops around central Tokyo, providing access to 
            major districts. IC cards like Pasmo and Suica offer convenient payment for all public 
            transportation. Buses complement the rail network, while taxis provide reliable door-to-door 
            service. The system handles over 40 million passengers daily with remarkable precision.
            """,
            "weather": """
            Tokyo experiences four distinct seasons. Spring (March-May) brings mild temperatures and 
            famous cherry blossoms, with temperatures ranging from 10-20°C (50-68°F). Summers 
            (June-August) are hot and humid, often exceeding 30°C (86°F), with a rainy season in 
            June. Autumn (September-November) offers comfortable temperatures and colorful foliage. 
            Winters (December-February) are cool and dry, with temperatures rarely falling below 
            0°C (32°F). The city averages 1,528mm of annual rainfall.
            """
        }
    ]
    
    documents = []
    for dest in destinations:
        content = f"""
        {dest['city']}, {dest['country']} - Comprehensive Travel Guide
        
        Overview and History:
        {dest['description']}
        
        Cultural Significance:
        {DestinationEnricher.add_cultural_context(dest['city'], dest['country'])}
        
        Detailed Attractions Guide:
        {format_attractions(dest['attractions'])}
        
        Culinary Landscape:
        Traditional Cuisine: {format_cuisine(dest['cuisine'])}
        
        Dining Scene:
        - Michelin-starred restaurants
        - Local food markets
        - Street food culture
        - Traditional dining etiquette
        - Popular food districts
        - Contemporary fusion cuisine
        
        Transportation Network:
        {dest['transportation']}
        
        Climate and Seasonal Considerations:
        {dest['weather']}
        
        Seasonal Events and Festivals:
        {DestinationEnricher.add_seasonal_events(dest['city'])}
        
        Practical Travel Information:
        - Visa requirements and entry procedures
        - Currency and banking facilities
        - Emergency services and healthcare
        - Communication and internet access
        - Shopping districts and local markets
        - Entertainment venues and nightlife
        - Cultural etiquette and customs
        - Language essentials for travelers
        
        Neighborhood Guide:
        - Popular residential areas
        - Business districts
        - Tourist hotspots
        - Historical quarters
        - Modern developments
        - Entertainment zones
        
        Accommodation Options:
        - Luxury hotels
        - Boutique properties
        - Business hotels
        - Budget accommodations
        - Traditional lodging
        - Serviced apartments
        
        Safety and Security:
        - General safety tips
        - Emergency contacts
        - Tourist police information
        - Health and medical facilities
        - Natural disaster preparedness
        """
        
        doc = Document(
            page_content=content,
            metadata={
                "type": "destination_info",
                "city": dest['city'],
                "country": dest['country'],
                "attractions": dest['attractions'],
                "cuisine": dest['cuisine']
            }
        )
        documents.append(doc)
    
    return documents

# %%
def format_attractions(attractions: List[str]) -> str:
    """Format attractions with detailed descriptions."""
    formatted = []
    for attraction in attractions:
        formatted.append(f"""
        {attraction}:
        - Historical significance and background
        - Visitor information and access
        - Best times to visit
        - Cultural importance
        - Photography opportunities
        - Guided tour options
        - Nearby facilities
        """)
    return "\n".join(formatted)

# %%
def format_cuisine(cuisine: List[str]) -> str:
    """Format cuisine information with detailed descriptions."""
    formatted = []
    for dish in cuisine:
        formatted.append(f"""
        {dish}:
        - Traditional preparation methods
        - Cultural significance
        - Best places to try
        - Seasonal variations
        - Typical ingredients
        - Pairing recommendations
        """)
    return "\n".join(formatted)

# %%
def build_travel_knowledge_base() -> FAISS:
    """Enhanced version of build_travel_knowledge_base with comprehensive context."""
    all_documents = []
    
    # Start with static destination information
    print("Collecting static destination information...")
    all_documents.extend(prepare_destination_info())
    
    # Fetch dynamic information from Amadeus API
    print("Fetching popular destinations from NYC...")
    all_documents.extend(fetch_popular_destinations('NYC'))
    
    # Fetch hotel information for major cities
    major_cities = ['PAR', 'LON', 'NYC', 'TYO', 'ROM']
    print("Fetching hotel information for major cities...")
    for city_code in major_cities:
        print(f"Processing {city_code}...")
        all_documents.extend(fetch_hotel_information(city_code))
    
    # Fetch flight offers for popular routes
    print("Fetching flight offers for popular routes...")
    next_month = (datetime.now() + timedelta(days=30)).strftime('%Y-%m-%d')
    popular_routes = [
        ('NYC', 'LON'), ('NYC', 'PAR'), ('NYC', 'ROM'),
        ('LON', 'PAR'), ('LON', 'ROM'), ('PAR', 'ROM')
    ]
    
    for origin, destination in popular_routes:
        print(f"Processing route {origin} to {destination}...")
        all_documents.extend(fetch_flight_offers(origin, destination, next_month))
    
    # Create text splitter with larger chunk size for RAGAS
    print("Splitting documents into chunks...")
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=3000,  # Increased for RAGAS compatibility
        chunk_overlap=300,
        length_function=len,
        separators=["\n\n", "\n", " ", ""]
    )
    split_documents = text_splitter.split_documents(all_documents)
    
    # Create and return vector store
    print(f"Building vector store with {len(split_documents)} documents...")
    vector_store = FAISS.from_documents(
        documents=split_documents,
        embedding=OpenAIEmbeddings()
    )
    
    print("Knowledge base built successfully!")
    return vector_store

# %%
# Build the knowledge base
travel_db = build_travel_knowledge_base()
print(f"Knowledge base built with {len(travel_db.index_to_docstore_id)} documents")
# Out:
# Collecting static destination information...
# Fetching popular destinations from NYC...
# Fetching hotel information for major cities...
# Processing PAR...
# Processing LON...
# Processing NYC...
# Processing TYO...
# Processing ROM...
# Fetching flight offers for popular routes...
# Processing route NYC to LON...
# Processing route NYC to PAR...
# Processing route NYC to ROM...
# Processing route LON to PAR...
# Processing route LON to ROM...
# Processing route PAR to ROM...
# Error fetching flight offers: [---]
# Splitting documents into chunks...
# Building vector store with 2663 documents...
# Knowledge base built successfully!
# Knowledge base built with 2663 documents

# %%
# Print each document in the vector store
for index, doc_id in travel_db.index_to_docstore_id.items():
    doc = travel_db.docstore.search(doc_id)
    char_length = len(doc.page_content)
    word_length = len(doc.page_content.split())
    print(f"Index: {index}")
    print(f"Document ID: {doc_id}")
    print(f"Length: {char_length} characters, {word_length} words")
    print(f"Content: {doc.page_content[:500]}...")  # Print first 500 chars
    print(f"Metadata: {doc.metadata}\n")
# Out:
# Index: 0
# Document ID: da7c5a0f-2a45-4a96-bc2c-6d83d93761d9
# Length: 2774 characters, 312 words
# Content: Paris, France - Comprehensive Travel Guide
#
#         Overview and History:
#
#             Paris, the City of Light, stands as a global epicenter of art, fashion, gastronomy, and culture.
#             Founded in the 3rd century BC, the city has evolved through centuries of rich history to become
#             one of the world's most influential and visited capitals. Its urban landscape marries historic
#             architecture with contemporary innovation, while its cultural scene sp...
# Metadata: {'type': 'destination_info', 'city': 'Paris', 'country': 'France', 'attractions': ['Eiffel Tower', 'Louvre Museum', 'Notre-Dame Cathedral', 'Arc de Triomphe', 'Champs-Élysées', 'Montmartre', 'Palace of Versailles', 'Seine River', "Musée d'Orsay", 'Centre Pompidou'], 'cuisine': ['Croissants and French pastries', 'Coq au Vin', 'Beef Bourguignon', 'French cheese varieties', 'Escargots', 'Macarons', 'French wines', 'Haute cuisine restaurants', 'Traditional bistros', 'Michelin-starred establishments']}
#
# Index: 1
# Document ID: 2b0eaa97-8e11-4c0a-b618-03808c686449
# Length: 2887 characters, 301 words
# Content: Champs-Élysées:
#         - Historical significance and background
#         - Visitor information and access
#         - Best times to visit
#         - Cultural importance
#         - Photography opportunities
#         - Guided tour options
#         - Nearby facilities
#
#
#         Montmartre:
#         - Historical significance and background
#         - Visitor information and access
#         - Best times to visit
#         - Cultural importance
#         - Photography opportunities
#         - Guided tour op...
# Metadata: {'type': 'destination_info', 'city': 'Paris', 'country': 'France', 'attractions': ['Eiffel Tower', 'Louvre Museum', 'Notre-Dame Cathedral', 'Arc de Triomphe', 'Champs-Élysées', 'Montmartre', 'Palace of Versailles', 'Seine River', "Musée d'Orsay", 'Centre Pompidou'], 'cuisine': ['Croissants and French pastries', 'Coq au Vin', 'Beef Bourguignon', 'French cheese varieties', 'Escargots', 'Macarons', 'French wines', 'Haute cuisine restaurants', 'Traditional bistros', 'Michelin-starred establishments']}
#
# Index: 2
# Document ID: 2177082d-7c3f-4490-8d70-830a735399e9
# Length: 1139 characters, 114 words
# Content: Escargots:
#         - Traditional preparation methods
#         - Cultural significance
#         - Best places to try
#         - Seasonal variations
#         - Typical ingredients
#         - Pairing recommendations
#
#
#         Macarons:
#         - Traditional preparation methods
#         - Cultural significance
#         - Best places to try
#         - Seasonal variations
#         - Typical ingredients
#         - Pairing recommendations
#
#
#         French wines:
#         - Traditional preparation m...
# Metadata: {'type': 'destination_info', 'city': 'Paris', 'country': 'France', 'attractions': ['Eiffel Tower', 'Louvre Museum', 'Notre-Dame Cathedral', 'Arc de Triomphe', 'Champs-Élysées', 'Montmartre', 'Palace of Versailles', 'Seine River', "Musée d'Orsay", 'Centre Pompidou'], 'cuisine': ['Croissants and French pastries', 'Coq au Vin', 'Beef Bourguignon', 'French cheese varieties', 'Escargots', 'Macarons', 'French wines', 'Haute cuisine restaurants', 'Traditional bistros', 'Michelin-starred establishments']}
#
# Index: 3
# Document ID: 3c8e1a20-643a-474b-9291-2f1c297a5b2f
# Length: 2960 characters, 303 words
# Content: Michelin-starred establishments:
#         - Traditional preparation methods
#         - Cultural significance
#         - Best places to try
#         - Seasonal variations
#         - Typical ingredients
#         - Pairing recommendations
#
#
#         Dining Scene:
#         - Michelin-starred restaurants
#         - Local food markets
#         - Street food culture
#         - Traditional dining etiquette
#         - Popular food districts
#         - Contemporary fusion cuisine
#
#         Trans...
# Metadata: {'type': 'destination_info', 'city': 'Paris', 'country': 'France', 'attractions': ['Eiffel Tower', 'Louvre Museum', 'Notre-Dame Cathedral', 'Arc de Triomphe', 'Champs-Élysées', 'Montmartre', 'Palace of Versailles', 'Seine River', "Musée d'Orsay", 'Centre Pompidou'], 'cuisine': ['Croissants and French pastries', 'Coq au Vin', 'Beef Bourguignon', 'French cheese varieties', 'Escargots', 'Macarons', 'French wines', 'Haute cuisine restaurants', 'Traditional bistros', 'Michelin-starred establishments']}
#
# Index: 4
# Document ID: 7dcfecb1-e796-4d0e-b2fd-251f76bf11eb
# Length: 992 characters, 106 words
# Content: - Visa requirements and entry procedures
#         - Currency and banking facilities
#         - Emergency services and healthcare
#         - Communication and internet access
#         - Shopping districts and local markets
#         - Entertainment venues and nightlife
#         - Cultural etiquette and customs
#         - Language essentials for travelers
#
#         Neighborhood Guide:
#         - Popular residential areas
#         - Business districts
#         - Tourist hotspots
#         - Historical qu...
# Metadata: {'type': 'destination_info', 'city': 'Paris', 'country': 'France', 'attractions': ['Eiffel Tower', 'Louvre Museum', 'Notre-Dame Cathedral', 'Arc de Triomphe', 'Champs-Élysées', 'Montmartre', 'Palace of Versailles', 'Seine River', "Musée d'Orsay", 'Centre Pompidou'], 'cuisine': ['Croissants and French pastries', 'Coq au Vin', 'Beef Bourguignon', 'French cheese varieties', 'Escargots', 'Macarons', 'French wines', 'Haute cuisine restaurants', 'Traditional bistros', 'Michelin-starred establishments']}
#
# Index: 5
# Document ID: f0f9a25a-a5bf-4050-b1cf-046cd152ee6d
# Length: 2750 characters, 306 words
# Content: Tokyo, Japan - Comprehensive Travel Guide
#
#         Overview and History:
#
#             Tokyo, Japan's bustling capital, is a city where ultramodern lives harmoniously with tradition.
#             From ancient temples to neon-lit skyscrapers, the city offers a fascinating blend of old and new.
#             As a global financial center and technology hub, Tokyo drives innovation while preserving its rich
#             cultural heritage. The city's 23 special wards each offer unique e...
# Metadata: {'type': 'destination_info', 'city': 'Tokyo', 'country': 'Japan', 'attractions': ['Senso-ji Temple', 'Tokyo Skytree', 'Meiji Shrine', 'Shibuya Crossing', 'Imperial Palace', 'Tsukiji Outer Market', 'Akihabara Electric Town', 'Ueno Park', 'Tokyo Tower', 'Ginza District'], 'cuisine': ['Sushi and sashimi', 'Ramen varieties', 'Tempura', 'Yakitori', 'Tonkatsu', 'Monjayaki', 'Japanese wagyu beef', 'Izakaya dining', 'Traditional kaiseki', 'Street food specialties']}
#
# Index: 6
# Document ID: 6a21d8fb-b137-439d-9580-233b9cf29d3a
# Length: 2863 characters, 299 words
# Content: Imperial Palace:
#         - Historical significance and background
#         - Visitor information and access
#         - Best times to visit
#         - Cultural importance
#         - Photography opportunities
#         - Guided tour options
#         - Nearby facilities
#
#
#         Tsukiji Outer Market:
#         - Historical significance and background
#         - Visitor information and access
#         - Best times to visit
#         - Cultural importance
#         - Photography opportunities
#         - Gui...
# Metadata: {'type': 'destination_info', 'city': 'Tokyo', 'country': 'Japan', 'attractions': ['Senso-ji Temple', 'Tokyo Skytree', 'Meiji Shrine', 'Shibuya Crossing', 'Imperial Palace', 'Tsukiji Outer Market', 'Akihabara Electric Town', 'Ueno Park', 'Tokyo Tower', 'Ginza District'], 'cuisine': ['Sushi and sashimi', 'Ramen varieties', 'Tempura', 'Yakitori', 'Tonkatsu', 'Monjayaki', 'Japanese wagyu beef', 'Izakaya dining', 'Traditional kaiseki', 'Street food specialties']}
#
# Index: 7
# Document ID: 1df2437e-620f-434d-8bbf-7bb15da19a2f
# Length: 1135 characters, 114 words
# Content: Tonkatsu:
#         - Traditional preparation methods
#         - Cultural significance
#         - Best places to try
#         - Seasonal variations
#         - Typical ingredients
#         - Pairing recommendations
#
#
#         Monjayaki:
#         - Traditional preparation methods
#         - Cultural significance
#         - Best places to try
#         - Seasonal variations
#         - Typical ingredients
#         - Pairing recommendations
#
#
#         Japanese wagyu beef:
#         - Traditional prepar...
# Metadata: {'type': 'destination_info', 'city': 'Tokyo', 'country': 'Japan', 'attractions': ['Senso-ji Temple', 'Tokyo Skytree', 'Meiji Shrine', 'Shibuya Crossing', 'Imperial Palace', 'Tsukiji Outer Market', 'Akihabara Electric Town', 'Ueno Park', 'Tokyo Tower', 'Ginza District'], 'cuisine': ['Sushi and sashimi', 'Ramen varieties', 'Tempura', 'Yakitori', 'Tonkatsu', 'Monjayaki', 'Japanese wagyu beef', 'Izakaya dining', 'Traditional kaiseki', 'Street food specialties']}
#
# Index: 8
# Document ID: 1a87a58e-ce42-4d88-aeef-e31c4e7a451d
# Length: 2937 characters, 313 words
# Content: Street food specialties:
#         - Traditional preparation methods
#         - Cultural significance
#         - Best places to try
#         - Seasonal variations
#         - Typical ingredients
#         - Pairing recommendations
#
#
#         Dining Scene:
#         - Michelin-starred restaurants
#         - Local food markets
#         - Street food culture
#         - Traditional dining etiquette
#         - Popular food districts
#         - Contemporary fusion cuisine
#
#         Transportatio...
# Metadata: {'type': 'destination_info', 'city': 'Tokyo', 'country': 'Japan', 'attractions': ['Senso-ji Temple', 'Tokyo Skytree', 'Meiji Shrine', 'Shibuya Crossing', 'Imperial Palace', 'Tsukiji Outer Market', 'Akihabara Electric Town', 'Ueno Park', 'Tokyo Tower', 'Ginza District'], 'cuisine': ['Sushi and sashimi', 'Ramen varieties', 'Tempura', 'Yakitori', 'Tonkatsu', 'Monjayaki', 'Japanese wagyu beef', 'Izakaya dining', 'Traditional kaiseki', 'Street food specialties']}
#
# Index: 9
# Document ID: 9e7c9195-25bc-40b5-8dd7-587ac40645ec
# Length: 850 characters, 79 words
# Content: Destination Analysis: MCO
#
#             Flight Information:
#             Departure Date: 2025-04-01
#             Return Date: 2025-04-02
#             Price: 55.97 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical ...
# Metadata: {'type': 'popular_destination', 'destination_code': 'MCO', 'price': '55.97', 'departure_date': '2025-04-01', 'return_date': '2025-04-02'}
#
# Index: 10
# Document ID: a58a188f-220e-49be-b47b-c6275ac579ac
# Length: 850 characters, 79 words
# Content: Destination Analysis: MIA
#
#             Flight Information:
#             Departure Date: 2025-03-11
#             Return Date: 2025-03-12
#             Price: 63.99 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical ...
# Metadata: {'type': 'popular_destination', 'destination_code': 'MIA', 'price': '63.99', 'departure_date': '2025-03-11', 'return_date': '2025-03-12'}
#
# Index: 11
# Document ID: a6abc15a-23ff-4ef4-9963-46db39a3008f
# Length: 850 characters, 79 words
# Content: Destination Analysis: FLL
#
#             Flight Information:
#             Departure Date: 2025-03-11
#             Return Date: 2025-03-12
#             Price: 67.99 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical ...
# Metadata: {'type': 'popular_destination', 'destination_code': 'FLL', 'price': '67.99', 'departure_date': '2025-03-11', 'return_date': '2025-03-12'}
#
# Index: 12
# Document ID: e4653caf-8e88-4fd8-aee1-2edda784cb61
# Length: 850 characters, 79 words
# Content: Destination Analysis: SJU
#
#             Flight Information:
#             Departure Date: 2025-03-18
#             Return Date: 2025-03-19
#             Price: 83.96 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical ...
# Metadata: {'type': 'popular_destination', 'destination_code': 'SJU', 'price': '83.96', 'departure_date': '2025-03-18', 'return_date': '2025-03-19'}
#
# Index: 13
# Document ID: 34b4326f-21df-403f-be89-105c188be8ca
# Length: 850 characters, 79 words
# Content: Destination Analysis: LAX
#
#             Flight Information:
#             Departure Date: 2025-05-06
#             Return Date: 2025-05-07
#             Price: 92.19 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical ...
# Metadata: {'type': 'popular_destination', 'destination_code': 'LAX', 'price': '92.19', 'departure_date': '2025-05-06', 'return_date': '2025-05-07'}
#
# Index: 14
# Document ID: 6ac4a3ad-706d-4246-966e-55733d859384
# Length: 850 characters, 79 words
# Content: Destination Analysis: LAS
#
#             Flight Information:
#             Departure Date: 2025-04-29
#             Return Date: 2025-04-30
#             Price: 97.97 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical ...
# Metadata: {'type': 'popular_destination', 'destination_code': 'LAS', 'price': '97.97', 'departure_date': '2025-04-29', 'return_date': '2025-04-30'}
#
# Index: 15
# Document ID: 7b79b151-dca6-4a58-b8c6-935b1e9831b4
# Length: 851 characters, 79 words
# Content: Destination Analysis: SFO
#
#             Flight Information:
#             Departure Date: 2025-03-26
#             Return Date: 2025-04-01
#             Price: 139.96 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'SFO', 'price': '139.96', 'departure_date': '2025-03-26', 'return_date': '2025-04-01'}
#
# Index: 16
# Document ID: 70c38149-bc51-4d9a-a805-80e7a6fe4e80
# Length: 851 characters, 79 words
# Content: Destination Analysis: SDQ
#
#             Flight Information:
#             Departure Date: 2025-03-05
#             Return Date: 2025-03-07
#             Price: 177.81 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'SDQ', 'price': '177.81', 'departure_date': '2025-03-05', 'return_date': '2025-03-07'}
#
# Index: 17
# Document ID: 3a28d6e1-5320-4e92-9237-7fd2959a53e7
# Length: 851 characters, 79 words
# Content: Destination Analysis: YTZ
#
#             Flight Information:
#             Departure Date: 2025-03-18
#             Return Date: 2025-03-19
#             Price: 234.62 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'YTZ', 'price': '234.62', 'departure_date': '2025-03-18', 'return_date': '2025-03-19'}
#
# Index: 18
# Document ID: b8b5c687-4b68-4d31-a7d8-ebdf99920879
# Length: 851 characters, 79 words
# Content: Destination Analysis: CUN
#
#             Flight Information:
#             Departure Date: 2025-03-03
#             Return Date: 2025-03-18
#             Price: 275.35 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'CUN', 'price': '275.35', 'departure_date': '2025-03-03', 'return_date': '2025-03-18'}
#
# Index: 19
# Document ID: 4b6db5fb-bfcd-4b4a-8653-800400c90765
# Length: 851 characters, 79 words
# Content: Destination Analysis: MEX
#
#             Flight Information:
#             Departure Date: 2025-03-03
#             Return Date: 2025-03-11
#             Price: 301.94 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'MEX', 'price': '301.94', 'departure_date': '2025-03-03', 'return_date': '2025-03-11'}
#
# Index: 20
# Document ID: 7541416a-2a62-40dd-bb8f-149b1f04565e
# Length: 851 characters, 79 words
# Content: Destination Analysis: DUB
#
#             Flight Information:
#             Departure Date: 2025-04-01
#             Return Date: 2025-04-08
#             Price: 379.01 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'DUB', 'price': '379.01', 'departure_date': '2025-04-01', 'return_date': '2025-04-08'}
#
# Index: 21
# Document ID: 16f95ca7-c142-4c13-9aaa-4b70c55ab956
# Length: 851 characters, 79 words
# Content: Destination Analysis: LHR
#
#             Flight Information:
#             Departure Date: 2025-04-25
#             Return Date: 2025-04-27
#             Price: 383.51 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'LHR', 'price': '383.51', 'departure_date': '2025-04-25', 'return_date': '2025-04-27'}
#
# Index: 22
# Document ID: 4601c41e-fbc9-4d30-a311-706e25974350
# Length: 851 characters, 79 words
# Content: Destination Analysis: LHR
#
#             Flight Information:
#             Departure Date: 2025-04-25
#             Return Date: 2025-04-27
#             Price: 383.51 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'LHR', 'price': '383.51', 'departure_date': '2025-04-25', 'return_date': '2025-04-27'}
#
# Index: 23
# Document ID: 7319cdb3-4975-4722-9b56-b8c53e566a4f
# Length: 851 characters, 79 words
# Content: Destination Analysis: ORY
#
#             Flight Information:
#             Departure Date: 2025-03-17
#             Return Date: 2025-03-20
#             Price: 399.71 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'ORY', 'price': '399.71', 'departure_date': '2025-03-17', 'return_date': '2025-03-20'}
#
# Index: 24
# Document ID: 9daadd60-bf97-4509-9219-779b7e4d1c7c
# Length: 851 characters, 79 words
# Content: Destination Analysis: MAD
#
#             Flight Information:
#             Departure Date: 2025-03-23
#             Return Date: 2025-03-27
#             Price: 409.01 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'MAD', 'price': '409.01', 'departure_date': '2025-03-23', 'return_date': '2025-03-27'}
#
# Index: 25
# Document ID: c4e4c03b-7c2c-4f9d-9239-a7c460da502c
# Length: 851 characters, 79 words
# Content: Destination Analysis: BCN
#
#             Flight Information:
#             Departure Date: 2025-03-23
#             Return Date: 2025-03-27
#             Price: 433.11 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'BCN', 'price': '433.11', 'departure_date': '2025-03-23', 'return_date': '2025-03-27'}
#
# Index: 26
# Document ID: 218576ce-1957-44ec-be52-ca6e300472e0
# Length: 851 characters, 79 words
# Content: Destination Analysis: LIS
#
#             Flight Information:
#             Departure Date: 2025-03-23
#             Return Date: 2025-03-25
#             Price: 435.31 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'LIS', 'price': '435.31', 'departure_date': '2025-03-23', 'return_date': '2025-03-25'}
#
# Index: 27
# Document ID: b089a894-0b50-410c-8893-95c57ecafb89
# Length: 851 characters, 79 words
# Content: Destination Analysis: MXP
#
#             Flight Information:
#             Departure Date: 2025-03-23
#             Return Date: 2025-03-25
#             Price: 437.31 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'MXP', 'price': '437.31', 'departure_date': '2025-03-23', 'return_date': '2025-03-25'}
#
# Index: 28
# Document ID: 92782dce-8d96-4181-a50d-0a5867bafeac
# Length: 851 characters, 79 words
# Content: Destination Analysis: MXP
#
#             Flight Information:
#             Departure Date: 2025-03-23
#             Return Date: 2025-03-27
#             Price: 437.31 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'MXP', 'price': '437.31', 'departure_date': '2025-03-23', 'return_date': '2025-03-27'}
#
# Index: 29
# Document ID: 357843a5-5ab2-4d0d-a508-02217b06d63a
# Length: 851 characters, 79 words
# Content: Destination Analysis: AMS
#
#             Flight Information:
#             Departure Date: 2025-03-23
#             Return Date: 2025-03-27
#             Price: 438.71 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'AMS', 'price': '438.71', 'departure_date': '2025-03-23', 'return_date': '2025-03-27'}
#
# Index: 30
# Document ID: 18835dd3-e945-4d3b-a61b-0f21dd2ab46c
# Length: 851 characters, 79 words
# Content: Destination Analysis: FCO
#
#             Flight Information:
#             Departure Date: 2025-03-25
#             Return Date: 2025-04-01
#             Price: 444.81 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'FCO', 'price': '444.81', 'departure_date': '2025-03-25', 'return_date': '2025-04-01'}
#
# Index: 31
# Document ID: bfb9edca-2b87-4069-974f-d9411f19f09f
# Length: 851 characters, 79 words
# Content: Destination Analysis: LIM
#
#             Flight Information:
#             Departure Date: 2025-04-29
#             Return Date: 2025-05-14
#             Price: 497.67 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'LIM', 'price': '497.67', 'departure_date': '2025-04-29', 'return_date': '2025-05-14'}
#
# Index: 32
# Document ID: 68d7c479-3b76-473c-bed0-13df62cf9759
# Length: 851 characters, 79 words
# Content: Destination Analysis: LGW
#
#             Flight Information:
#             Departure Date: 2025-03-23
#             Return Date: 2025-03-27
#             Price: 500.91 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'LGW', 'price': '500.91', 'departure_date': '2025-03-23', 'return_date': '2025-03-27'}
#
# Index: 33
# Document ID: 898937d8-9f79-4d2f-92a1-f713ac8ff744
# Length: 851 characters, 79 words
# Content: Destination Analysis: TLV
#
#             Flight Information:
#             Departure Date: 2025-03-23
#             Return Date: 2025-03-26
#             Price: 533.89 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'TLV', 'price': '533.89', 'departure_date': '2025-03-23', 'return_date': '2025-03-26'}
#
# Index: 34
# Document ID: 39f0f0c2-88ca-4adf-b3c8-e4a4f456b835
# Length: 851 characters, 79 words
# Content: Destination Analysis: ATH
#
#             Flight Information:
#             Departure Date: 2025-03-31
#             Return Date: 2025-04-14
#             Price: 562.11 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'ATH', 'price': '562.11', 'departure_date': '2025-03-31', 'return_date': '2025-04-14'}
#
# Index: 35
# Document ID: 067828d0-bc71-4eaf-8f04-6660764002e9
# Length: 851 characters, 79 words
# Content: Destination Analysis: BOM
#
#             Flight Information:
#             Departure Date: 2025-03-10
#             Return Date: 2025-03-25
#             Price: 569.96 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'BOM', 'price': '569.96', 'departure_date': '2025-03-10', 'return_date': '2025-03-25'}
#
# Index: 36
# Document ID: 76b8924d-76f9-4912-99af-1a5430e5b731
# Length: 851 characters, 79 words
# Content: Destination Analysis: CAI
#
#             Flight Information:
#             Departure Date: 2025-03-09
#             Return Date: 2025-03-24
#             Price: 628.09 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'CAI', 'price': '628.09', 'departure_date': '2025-03-09', 'return_date': '2025-03-24'}
#
# Index: 37
# Document ID: 5279d421-0667-4ac2-9d8e-476f38df731d
# Length: 851 characters, 79 words
# Content: Destination Analysis: DEL
#
#             Flight Information:
#             Departure Date: 2025-05-03
#             Return Date: 2025-05-18
#             Price: 667.75 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'DEL', 'price': '667.75', 'departure_date': '2025-05-03', 'return_date': '2025-05-18'}
#
# Index: 38
# Document ID: d5be9c3f-09be-47e6-a8ec-2ace4e33e3ca
# Length: 851 characters, 79 words
# Content: Destination Analysis: BKK
#
#             Flight Information:
#             Departure Date: 2025-03-04
#             Return Date: 2025-03-11
#             Price: 822.11 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'BKK', 'price': '822.11', 'departure_date': '2025-03-04', 'return_date': '2025-03-11'}
#
# Index: 39
# Document ID: d366d529-4979-4267-8457-a684b9e26753
# Length: 851 characters, 79 words
# Content: Destination Analysis: MNL
#
#             Flight Information:
#             Departure Date: 2025-03-04
#             Return Date: 2025-03-12
#             Price: 860.91 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'MNL', 'price': '860.91', 'departure_date': '2025-03-04', 'return_date': '2025-03-12'}
#
# Index: 40
# Document ID: b5a5e807-e27a-4fc2-b8e0-a503724761c2
# Length: 851 characters, 79 words
# Content: Destination Analysis: NRT
#
#             Flight Information:
#             Departure Date: 2025-02-28
#             Return Date: 2025-03-07
#             Price: 922.23 USD
#
#             Travel Insights:
#             - Peak vs. Off-peak season analysis
#             - Price trends and historical data
#             - Popular connecting routes
#             - Typical flight durations and time zones
#
#             Destination Background:
#             Detailed cultural and historical...
# Metadata: {'type': 'popular_destination', 'destination_code': 'NRT', 'price': '922.23', 'departure_date': '2025-02-28', 'return_date': '2025-03-07'}
#
# Index: 41
# Document ID: edff1078-c651-4590-bd6c-b6d0964ee82a
# Length: 2963 characters, 290 words
# Content: Hotel Comprehensive Profile: HOTEL RESIDENCE EUROPE
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.87321,
#                             2.32541
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Apartment Hotel
#             Last Updated: 2023-06-15T09:57:36
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     -...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPAR733', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.87321, 'longitude': 2.32541}}
#
# Index: 42
# Document ID: 06c2ec3f-314c-4e20-9fa8-412f14a478d0
# Length: 2973 characters, 291 words
# Content: Hotel Comprehensive Profile: RESIDENCE CERISE MAISONS LAFFITTE
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.94579,
#                             2.1516
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Apartment Hotel
#             Last Updated: 2023-06-15T10:29:18
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and ...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPAR163', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.94579, 'longitude': 2.1516}}
#
# Index: 43
# Document ID: 39fd8297-00ee-4fa5-8f68-8f69c8d6793b
# Length: 2956 characters, 290 words
# Content: Hotel Comprehensive Profile: HOTEL DU CHATEAU
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.84869,
#                             2.36805
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T09:58:54
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     - Safety...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPAR571', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.84869, 'longitude': 2.36805}}
#
# Index: 44
# Document ID: 4d55fd71-13d6-40aa-a5e7-c021d122ebf9
# Length: 2963 characters, 291 words
# Content: Hotel Comprehensive Profile: HOTEL ALBE SAINT MICHEL
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.83957,
#                             2.32297
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T10:28:30
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     -...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPARD48', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.83957, 'longitude': 2.32297}}
#
# Index: 45
# Document ID: 21867d11-528e-4a59-9e96-c230489984b6
# Length: 2952 characters, 290 words
# Content: Hotel Comprehensive Profile: LE NOTRE DAME
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.8566,
#                             2.33027
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T09:56:02
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     - Safety and...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPAR419', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.8566, 'longitude': 2.33027}}
#
# Index: 46
# Document ID: 1d557d22-57ec-4aeb-a7e0-9d2d4e172fba
# Length: 2957 characters, 290 words
# Content: Hotel Comprehensive Profile: ETOILE PARK HOTEL
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.87615,
#                             2.29463
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T10:15:08
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     - Safet...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPARE24', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.87615, 'longitude': 2.29463}}
#
# Index: 47
# Document ID: 950d4a7a-c885-4a1d-8c23-6f663257081b
# Length: 2957 characters, 289 words
# Content: Hotel Comprehensive Profile: ALEXANDRINE OPERA
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.87569,
#                             2.28632
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T11:09:06
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     - Safet...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPARF08', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.87569, 'longitude': 2.28632}}
#
# Index: 48
# Document ID: d3515742-a2d2-47ea-b4ce-82ea0432a106
# Length: 2949 characters, 289 words
# Content: Hotel Comprehensive Profile: DU CADRAN
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.85647,
#                             2.30592
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T09:57:20
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     - Safety and se...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPAR478', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.85647, 'longitude': 2.30592}}
#
# Index: 49
# Document ID: 42aa9257-442f-4145-aa95-ee3308be8582
# Length: 2955 characters, 288 words
# Content: Hotel Comprehensive Profile: MONCEAU-ELYSEES
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.87913,
#                             2.34347
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T09:54:59
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     - Safety ...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPAR376', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.87913, 'longitude': 2.34347}}
#
# Index: 50
# Document ID: 28691510-0484-4224-87fa-c3277eca11b0
# Length: 2961 characters, 290 words
# Content: Hotel Comprehensive Profile: FRANCE QUARTIER LATIN
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.87905,
#                             2.29232
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T10:11:44
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     - S...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPAR208', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.87905, 'longitude': 2.29232}}
#
# Index: 51
# Document ID: 2b6cc3c1-6719-49b1-a096-33fe366ca6b5
# Length: 2963 characters, 291 words
# Content: Hotel Comprehensive Profile: CECILIA ARC DE TRIOMPHE
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.87604,
#                             2.29466
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T11:06:36
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     -...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPARE22', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.87604, 'longitude': 2.29466}}
#
# Index: 52
# Document ID: 578ce77c-02b4-4a53-a71d-dcb4b74a154b
# Length: 2950 characters, 289 words
# Content: Hotel Comprehensive Profile: FRED HOTEL
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.86513,
#                             2.34197
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T10:26:09
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     - Safety and s...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPARD16', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.86513, 'longitude': 2.34197}}
#
# Index: 53
# Document ID: ef0cb95c-6a6a-405b-9328-d6349c0030bc
# Length: 2969 characters, 292 words
# Content: Hotel Comprehensive Profile: LE CHAPLAIN PARIS RIVE GAUCHE
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.84292,
#                             2.33036
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2025-02-24T09:00:19
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPARCHA', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.84292, 'longitude': 2.33036}}
#
# Index: 54
# Document ID: c932cbb9-69b0-4599-9a27-b1f4e27f0263
# Length: 2948 characters, 288 words
# Content: Hotel Comprehensive Profile: CORDELIA
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.87321,
#                             2.32541
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T09:56:33
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     - Safety and sec...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPAR707', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.87321, 'longitude': 2.32541}}
#
# Index: 55
# Document ID: 8eadfee4-1ca7-420e-af92-96c07721b648
# Length: 2954 characters, 290 words
# Content: Hotel Comprehensive Profile: HOTEL DU TEMPS
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.87105,
#                             2.32037
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T10:03:22
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     - Safety a...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPARB26', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.87105, 'longitude': 2.32037}}
#
# Index: 56
# Document ID: 7703763d-fd8e-4b1a-8e3d-c97f1699d9f1
# Length: 2954 characters, 289 words
# Content: Hotel Comprehensive Profile: ACACIAS ETOILE
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.85535,
#                             2.33085
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T10:18:48
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     - Safety a...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPARA87', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.85535, 'longitude': 2.33085}}
#
# Index: 57
# Document ID: 6c05b940-f7b9-4f31-9437-a609823ac49d
# Length: 2954 characters, 290 words
# Content: Hotel Comprehensive Profile: HOTEL B SQUARE
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.86929,
#                             2.35896
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T10:11:13
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
#     - Safety a...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPAR181', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.86929, 'longitude': 2.35896}}
#
# Index: 58
# Document ID: ae95f48e-d801-4499-a247-36aca5b1f5a5
# Length: 2968 characters, 290 words
# Content: Hotel Comprehensive Profile: CHATILLON PARIS MONTPARNASSE
#
#             Location Analysis:
#             City: PAR
#             Precise Location: 48.82576,
#                             2.32323
#             Country: FR
#
#             Property Details:
#             Chain: AC
#             Category: Standard Hotel
#             Last Updated: 2023-06-15T09:46:20
#
#             Neighborhood Overview:
#
#     Neighborhood Characteristics:
#     - Local atmosphere and vibe
# ...
# Metadata: {'type': 'hotel_information', 'hotel_id': 'ACPAR900', 'city_code': 'PAR', 'chain_code': 'AC', 'location': {'latitude': 48.82576, 'longitude': 2.32323}}
#
# Index: 59
# ...
#
# Index: 2641
# Document ID: f7cbb861-83ab-46c5-a603-0fa505cf6f37
# Length: 2977 characters, 237 words
# Content: Comprehensive Flight Analysis: LON to PAR
#
#             Route Overview:
#
#     Route Characteristics:
#     - Distance and typical duration
#     - Common connection points
#     - Seasonal weather impact
#     - Time zone considerations
#
#     Market Analysis:
#     - Popular travel periods
#     - Price fluctuation patterns
#     - Competing airlines
#     - Alternative routes
#
#     Operational Considerations:
#     - Aircraft types commonly used
#     - Typical delays and causes
#     - S...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'PAR', 'departure_date': '2025-03-26', 'price': '133.77', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2642
# Document ID: 1c48a98b-98e1-400c-8a52-255210f78b33
# Length: 986 characters, 102 words
# Content: Amenities:
#     - Dining options
#     - Shopping facilities
#     - Business services
#     - Medical facilities
#
#
#     Airport: PAR
#
#     Terminal Information:
#     - Layout and facilities
#     - Transfer processes
#     - Security procedures
#     - Lounges and services
#
#     Ground Transportation:
#     - Public transit options
#     - Taxi and ride-share
#     - Car rental facilities
#     - Parking services
#
#     Amenities:
#     - Dining options
#     - Shopping facilities
#     - Business s...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'PAR', 'departure_date': '2025-03-26', 'price': '133.77', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2643
# Document ID: 7e9baa58-61cf-4b3f-bed0-8315a7cae1f9
# Length: 2942 characters, 265 words
# Content: Comprehensive Flight Analysis: LON to ROM
#
#             Route Overview:
#
#     Route Characteristics:
#     - Distance and typical duration
#     - Common connection points
#     - Seasonal weather impact
#     - Time zone considerations
#
#     Market Analysis:
#     - Popular travel periods
#     - Price fluctuation patterns
#     - Competing airlines
#     - Alternative routes
#
#     Operational Considerations:
#     - Aircraft types commonly used
#     - Typical delays and causes
#     - S...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '75.48', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2644
# Document ID: 5f8669c6-d194-43b2-8580-5bd1fbda5836
# Length: 311 characters, 30 words
# Content: - Baggage policies
#             - Transit visa requirements
#             - Connection considerations
#
#             Additional Services:
#             - Available ancillary services
#             - Lounge access details
#             - Special assistance services
#             - Meal and seat selection options...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '75.48', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2645
# Document ID: d847fa0d-e5c3-457e-b251-f08bdff05f0b
# Length: 2942 characters, 265 words
# Content: Comprehensive Flight Analysis: LON to ROM
#
#             Route Overview:
#
#     Route Characteristics:
#     - Distance and typical duration
#     - Common connection points
#     - Seasonal weather impact
#     - Time zone considerations
#
#     Market Analysis:
#     - Popular travel periods
#     - Price fluctuation patterns
#     - Competing airlines
#     - Alternative routes
#
#     Operational Considerations:
#     - Aircraft types commonly used
#     - Typical delays and causes
#     - S...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '75.48', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2646
# Document ID: c62e2bcd-d412-40a9-a1fe-059550ada82a
# Length: 311 characters, 30 words
# Content: - Baggage policies
#             - Transit visa requirements
#             - Connection considerations
#
#             Additional Services:
#             - Available ancillary services
#             - Lounge access details
#             - Special assistance services
#             - Meal and seat selection options...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '75.48', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2647
# Document ID: 5cb21056-9c78-460b-9408-db0c945a4cc8
# Length: 2972 characters, 237 words
# Content: Comprehensive Flight Analysis: LON to ROM
#
#             Route Overview:
#
#     Route Characteristics:
#     - Distance and typical duration
#     - Common connection points
#     - Seasonal weather impact
#     - Time zone considerations
#
#     Market Analysis:
#     - Popular travel periods
#     - Price fluctuation patterns
#     - Competing airlines
#     - Alternative routes
#
#     Operational Considerations:
#     - Aircraft types commonly used
#     - Typical delays and causes
#     - S...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '101.99', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2648
# Document ID: 7c9eb52a-a1c0-4641-a701-537898dc5572
# Length: 986 characters, 102 words
# Content: Amenities:
#     - Dining options
#     - Shopping facilities
#     - Business services
#     - Medical facilities
#
#
#     Airport: ROM
#
#     Terminal Information:
#     - Layout and facilities
#     - Transfer processes
#     - Security procedures
#     - Lounges and services
#
#     Ground Transportation:
#     - Public transit options
#     - Taxi and ride-share
#     - Car rental facilities
#     - Parking services
#
#     Amenities:
#     - Dining options
#     - Shopping facilities
#     - Business s...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '101.99', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2649
# Document ID: 98b93941-f1b1-4e6c-a743-d8784454d8e9
# Length: 2943 characters, 265 words
# Content: Comprehensive Flight Analysis: LON to ROM
#
#             Route Overview:
#
#     Route Characteristics:
#     - Distance and typical duration
#     - Common connection points
#     - Seasonal weather impact
#     - Time zone considerations
#
#     Market Analysis:
#     - Popular travel periods
#     - Price fluctuation patterns
#     - Competing airlines
#     - Alternative routes
#
#     Operational Considerations:
#     - Aircraft types commonly used
#     - Typical delays and causes
#     - S...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '119.32', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2650
# Document ID: f31374fd-3ca0-4fb1-b081-c393f373082e
# Length: 311 characters, 30 words
# Content: - Baggage policies
#             - Transit visa requirements
#             - Connection considerations
#
#             Additional Services:
#             - Available ancillary services
#             - Lounge access details
#             - Special assistance services
#             - Meal and seat selection options...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '119.32', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2651
# Document ID: f32ac00e-544d-446c-81fe-6fcee5be1e61
# Length: 2943 characters, 265 words
# Content: Comprehensive Flight Analysis: LON to ROM
#
#             Route Overview:
#
#     Route Characteristics:
#     - Distance and typical duration
#     - Common connection points
#     - Seasonal weather impact
#     - Time zone considerations
#
#     Market Analysis:
#     - Popular travel periods
#     - Price fluctuation patterns
#     - Competing airlines
#     - Alternative routes
#
#     Operational Considerations:
#     - Aircraft types commonly used
#     - Typical delays and causes
#     - S...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '119.32', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2652
# Document ID: 714ff73a-8d4a-40cc-96ac-579d10fa6555
# Length: 311 characters, 30 words
# Content: - Baggage policies
#             - Transit visa requirements
#             - Connection considerations
#
#             Additional Services:
#             - Available ancillary services
#             - Lounge access details
#             - Special assistance services
#             - Meal and seat selection options...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '119.32', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2653
# Document ID: c2bc5311-35b4-4895-8a33-132d7e7d8d60
# Length: 2974 characters, 237 words
# Content: Comprehensive Flight Analysis: LON to ROM
#
#             Route Overview:
#
#     Route Characteristics:
#     - Distance and typical duration
#     - Common connection points
#     - Seasonal weather impact
#     - Time zone considerations
#
#     Market Analysis:
#     - Popular travel periods
#     - Price fluctuation patterns
#     - Competing airlines
#     - Alternative routes
#
#     Operational Considerations:
#     - Aircraft types commonly used
#     - Typical delays and causes
#     - S...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '126.27', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2654
# Document ID: dff71dcc-53fc-433f-ab2f-60cc2fe8f397
# Length: 986 characters, 102 words
# Content: Amenities:
#     - Dining options
#     - Shopping facilities
#     - Business services
#     - Medical facilities
#
#
#     Airport: ROM
#
#     Terminal Information:
#     - Layout and facilities
#     - Transfer processes
#     - Security procedures
#     - Lounges and services
#
#     Ground Transportation:
#     - Public transit options
#     - Taxi and ride-share
#     - Car rental facilities
#     - Parking services
#
#     Amenities:
#     - Dining options
#     - Shopping facilities
#     - Business s...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '126.27', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2655
# Document ID: a126f4f1-036b-4c50-bb67-67f11ed515d5
# Length: 2974 characters, 237 words
# Content: Comprehensive Flight Analysis: LON to ROM
#
#             Route Overview:
#
#     Route Characteristics:
#     - Distance and typical duration
#     - Common connection points
#     - Seasonal weather impact
#     - Time zone considerations
#
#     Market Analysis:
#     - Popular travel periods
#     - Price fluctuation patterns
#     - Competing airlines
#     - Alternative routes
#
#     Operational Considerations:
#     - Aircraft types commonly used
#     - Typical delays and causes
#     - S...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '126.27', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2656
# Document ID: f9269c7c-5422-4868-981a-b6c2f1097f33
# Length: 986 characters, 102 words
# Content: Amenities:
#     - Dining options
#     - Shopping facilities
#     - Business services
#     - Medical facilities
#
#
#     Airport: ROM
#
#     Terminal Information:
#     - Layout and facilities
#     - Transfer processes
#     - Security procedures
#     - Lounges and services
#
#     Ground Transportation:
#     - Public transit options
#     - Taxi and ride-share
#     - Car rental facilities
#     - Parking services
#
#     Amenities:
#     - Dining options
#     - Shopping facilities
#     - Business s...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '126.27', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2657
# Document ID: bc373096-7ddd-4cb4-8e4c-d2333a1ece2a
# Length: 2943 characters, 265 words
# Content: Comprehensive Flight Analysis: LON to ROM
#
#             Route Overview:
#
#     Route Characteristics:
#     - Distance and typical duration
#     - Common connection points
#     - Seasonal weather impact
#     - Time zone considerations
#
#     Market Analysis:
#     - Popular travel periods
#     - Price fluctuation patterns
#     - Competing airlines
#     - Alternative routes
#
#     Operational Considerations:
#     - Aircraft types commonly used
#     - Typical delays and causes
#     - S...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '135.32', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2658
# Document ID: ec8ccd3f-dcb2-4f1c-a96f-b68001e491a5
# Length: 311 characters, 30 words
# Content: - Baggage policies
#             - Transit visa requirements
#             - Connection considerations
#
#             Additional Services:
#             - Available ancillary services
#             - Lounge access details
#             - Special assistance services
#             - Meal and seat selection options...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '135.32', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2659
# Document ID: ea92a45d-d025-49ac-842e-86498f9d8888
# Length: 2943 characters, 265 words
# Content: Comprehensive Flight Analysis: LON to ROM
#
#             Route Overview:
#
#     Route Characteristics:
#     - Distance and typical duration
#     - Common connection points
#     - Seasonal weather impact
#     - Time zone considerations
#
#     Market Analysis:
#     - Popular travel periods
#     - Price fluctuation patterns
#     - Competing airlines
#     - Alternative routes
#
#     Operational Considerations:
#     - Aircraft types commonly used
#     - Typical delays and causes
#     - S...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '135.32', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2660
# Document ID: 7116b7db-0c09-4850-a255-0de5e3706c40
# Length: 311 characters, 30 words
# Content: - Baggage policies
#             - Transit visa requirements
#             - Connection considerations
#
#             Additional Services:
#             - Available ancillary services
#             - Lounge access details
#             - Special assistance services
#             - Meal and seat selection options...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '135.32', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2661
# Document ID: 84144ce8-7e49-4520-bcef-be91c78c33a7
# Length: 2973 characters, 237 words
# Content: Comprehensive Flight Analysis: LON to ROM
#
#             Route Overview:
#
#     Route Characteristics:
#     - Distance and typical duration
#     - Common connection points
#     - Seasonal weather impact
#     - Time zone considerations
#
#     Market Analysis:
#     - Popular travel periods
#     - Price fluctuation patterns
#     - Competing airlines
#     - Alternative routes
#
#     Operational Considerations:
#     - Aircraft types commonly used
#     - Typical delays and causes
#     - S...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '155.99', 'currency': 'EUR', 'booking_class': 'N/A'}
#
# Index: 2662
# Document ID: 07e2d300-bacc-4f40-9130-c8506a7a8148
# Length: 986 characters, 102 words
# Content: Amenities:
#     - Dining options
#     - Shopping facilities
#     - Business services
#     - Medical facilities
#
#
#     Airport: ROM
#
#     Terminal Information:
#     - Layout and facilities
#     - Transfer processes
#     - Security procedures
#     - Lounges and services
#
#     Ground Transportation:
#     - Public transit options
#     - Taxi and ride-share
#     - Car rental facilities
#     - Parking services
#
#     Amenities:
#     - Dining options
#     - Shopping facilities
#     - Business s...
# Metadata: {'type': 'flight_offer', 'origin': 'LON', 'destination': 'ROM', 'departure_date': '2025-03-26', 'price': '155.99', 'currency': 'EUR', 'booking_class': 'N/A'}

# %%
import numpy as np
from statistics import median

# Get all document lengths
doc_lengths = [len(travel_db.docstore.search(doc_id).page_content) 
               for doc_id in travel_db.index_to_docstore_id.values()]

# Calculate statistics
max_len = max(doc_lengths)
min_len = min(doc_lengths)
mean_len = np.mean(doc_lengths)
median_len = median(doc_lengths)

print(f"Document Length Statistics:")
print(f"Maximum length: {max_len:,} characters")
print(f"Minimum length: {min_len:,} characters")
print(f"Mean length: {mean_len:,.2f} characters")
print(f"Median length: {median_len:,} characters")

# If you want word counts too
word_lengths = [len(travel_db.docstore.search(doc_id).page_content.split()) 
                for doc_id in travel_db.index_to_docstore_id.values()]

print(f"\nWord Count Statistics:")
print(f"Maximum words: {max(word_lengths):,}")
print(f"Minimum words: {min(word_lengths):,}")
print(f"Mean words: {np.mean(word_lengths):,.2f}")
print(f"Median words: {median(word_lengths):,}")
# Out:
# Document Length Statistics:
# Maximum length: 2,987 characters
# Minimum length: 267 characters
# Mean length: 2,670.62 characters
# Median length: 2,857 characters
#
# Word Count Statistics:
# Maximum words: 313
# Minimum words: 22
# Mean words: 259.28
# Median words: 278

# %%
import pickle

# Save the vector store
travel_db.save_local("travel_db_faiss")

# Save the docstore separately (contains the actual documents)
with open('travel_db_docstore.pkl', 'wb') as f:
    pickle.dump(travel_db.docstore, f)
